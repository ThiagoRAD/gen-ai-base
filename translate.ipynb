# %%
from translate import Translator

# %%
translator = Translator(to_lang="pt-BR")
text = "Hello, how are you?"
translation = translator.translate(text)
print('Translated Text:', translation)
# Out:
# Translated Text: Olá, tudo bem?
