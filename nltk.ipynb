# %%
import nltk

nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\thiag\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
sample_text = "Some content about generative AI"
tokens = nltk.word_tokenize(sample_text)
print(tokens)
# Out:
# ['Some', 'content', 'about', 'generative', 'AI']

# %%
bigrams = list(nltk.ngrams(tokens, 2))
bigrams
# Out:
# [('Some', 'content'),
#  ('content', 'about'),
#  ('about', 'generative'),
#  ('generative', 'AI')]

# %%
sample_text = 'I am learning NLP(Natural Language Processing'
tokens = nltk.word_tokenize(sample_text)

# %%
# Unigram
unigrams = list(nltk.ngrams(tokens, 1))
print('Unigrams:', unigrams)

# Bigram
bigrams = list(nltk.ngrams(tokens, 2))
print('Bigrams:', bigrams)

# Trigram
trigrams = list(nltk.ngrams(tokens, 3))
print('Trigrams:', trigrams)
# Out:
# Unigrams: [('I',), ('am',), ('learning',), ('NLP',), ('(',), ('Natural',), ('Language',), ('Processing',)]
# Bigrams: [('I', 'am'), ('am', 'learning'), ('learning', 'NLP'), ('NLP', '('), ('(', 'Natural'), ('Natural', 'Language'), ('Language', 'Processing')]
# Trigrams: [('I', 'am', 'learning'), ('am', 'learning', 'NLP'), ('learning', 'NLP', '('), ('NLP', '(', 'Natural'), ('(', 'Natural', 'Language'), ('Natural', 'Language', 'Processing')]
